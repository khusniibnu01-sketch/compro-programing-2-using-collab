# %% [markdown]
# **STRING**

# %%
nama = 'ibnu sina'
asal = 'Indonesia'
#print (nama, asal)
#print ("halo nama saya", nama)
#print ("halo nama saya", nama, "asal saya dari", asal)
# Out:
# halo nama saya ibnu sina asal saya dari Indonesia

# %%
data_lengkap = nama +asal
print (data_lengkap)
# Out:
# ibnu sinaIndonesia

# %% [markdown]
# **STRING NON STRING**

# %%
asal_kota = "Bandar lampung"
kode_pos= "35144"
asal_kota_kode_pos = asal_kota + kode_pos
print (asal_kota_kode_pos)
# Out:
# Bandar lampung35144

# %%
asal_kota_x3 = asal_kota * 3
print (asal_kota_x3)
# Out:
# Bandar lampungBandar lampungBandar lampung
